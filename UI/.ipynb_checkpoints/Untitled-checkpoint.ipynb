# %%
from flask import Flask,redirect,url_for,render_template,request,jsonify
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI
import getpass
import os


from langchain_community.vectorstores.azuresearch import AzureSearch
from langchain_openai import AzureOpenAIEmbeddings, OpenAIEmbeddings

# LANGCHAIN_TRACING_V2=True
# LANGCHAIN_ENDPOINT="https://api.smith.langchain.com"
# LANGCHAIN_API_KEY="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"
# LANGCHAIN_PROJECT="pr-overcooked-density-92"


# index ednpoint : https://ragservice123.search.windows.net
# password : T3pbTL6NuePkLszHmaA03m81rVjdtv6Quv2oNZ1OXoAzSeDHmlbF


azure_endpoint: str = "https://gh018-m3fob2dq-swedencentral.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview"
azure_openai_api_key: str = "5JYysB7CedH4g26m0WwUhPqDgkcvDKu6PWVmMTwHfKpvhwZ6pbizJQQJ99AKACfhMk5XJ3w3AAAAACOGjeKe"
azure_openai_api_version: str = "2023-05-15"
azure_deployment: str = "text-embedding-ada-002"


vector_store_address: str = "https://ragservice123.search.windows.net"
vector_store_password: str = "T3pbTL6NuePkLszHmaA03m81rVjdtv6Quv2oNZ1OXoAzSeDHmlbF"

embeddings: AzureOpenAIEmbeddings = AzureOpenAIEmbeddings(
    azure_deployment=azure_deployment,
    openai_api_version=azure_openai_api_version,
    azure_endpoint=azure_endpoint,
    api_key=azure_openai_api_key,
)

index_name: str = "langchain-vector-demo"
vector_store: AzureSearch = AzureSearch(
    azure_search_endpoint=vector_store_address,
    azure_search_key=vector_store_password,
    index_name=index_name,
    embedding_function=embeddings.embed_query,
)


loader = TextLoader("Tickets.txt")
documents = loader.load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=500)
texts = text_splitter.split_documents(documents)

# vectorstore = Chroma.from_documents(
    # texts,
    # embedding=OpenAIEmbeddings(),
# )

retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 1},
)

message = """
Answer this question using the provided context only.

{question}

Context:
{context}
"""



llm = ChatOpenAI(model="gpt-4o")

prompt = ChatPromptTemplate.from_messages([("human", message)])

rag_chain = {"context": retriever, "question": RunnablePassthrough()} | prompt | llm
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[17], line 44
#      36 embeddings: AzureOpenAIEmbeddings = AzureOpenAIEmbeddings(
#      37     azure_deployment=azure_deployment,
#      38     openai_api_version=azure_openai_api_version,
#      39     azure_endpoint=azure_endpoint,
#      40     api_key=azure_openai_api_key,
#      41 )
#      43 index_name: str = "langchain-vector-demo"
# ---> 44 vector_store: AzureSearch = AzureSearch(
#      45     azure_search_endpoint=vector_store_address,
#      46     azure_search_key=vector_store_password,
#      47     index_name=index_name,
#      48     embedding_function=embeddings.embed_query,
#      49 )
#      52 loader = TextLoader("Tickets.txt")
#      53 documents = loader.load()
#
# ...

# %%
rag_chain.invoke('ticket')
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 rag_chain.invoke('ticket')
#
# File ~\.conda\envs\hack\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File ~\.conda\envs\hack\Lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
# ...

# %%
from flask import Flask,redirect,url_for,render_template,request,jsonify
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI
import getpass
import os


from langchain_community.vectorstores.azuresearch import AzureSearch
from langchain_openai import AzureOpenAIEmbeddings, OpenAIEmbeddings

# LANGCHAIN_TRACING_V2=True
# LANGCHAIN_ENDPOINT="https://api.smith.langchain.com"
# LANGCHAIN_API_KEY="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"
# LANGCHAIN_PROJECT="pr-overcooked-density-92"


# index ednpoint : https://ragservice123.search.windows.net
# password : T3pbTL6NuePkLszHmaA03m81rVjdtv6Quv2oNZ1OXoAzSeDHmlbF


azure_endpoint: str = "https://gh018-m3fob2dq-swedencentral.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview"
azure_openai_api_key: str = "5JYysB7CedH4g26m0WwUhPqDgkcvDKu6PWVmMTwHfKpvhwZ6pbizJQQJ99AKACfhMk5XJ3w3AAAAACOGjeKe"
azure_openai_api_version: str = "2023-05-15"
azure_deployment: str = "text-embedding-ada-002"


vector_store_address: str = "https://ragservice123.search.windows.net"
vector_store_password: str = "kYTk8LtHQDvTb2LnYqG09vbeBNSwEB1287MrZbqkgFAzSeCNW3gO"


embeddings: AzureOpenAIEmbeddings = AzureOpenAIEmbeddings(
    azure_deployment=azure_deployment,
    openai_api_version=azure_openai_api_version,
    azure_endpoint=azure_endpoint,
    api_key=azure_openai_api_key,
)

index_name: str = "langchain-vector-demo"
vector_store: AzureSearch = AzureSearch(
    azure_search_endpoint=vector_store_address,
    azure_search_key=vector_store_password,
    index_name=index_name,
    embedding_function=embeddings.embed_query,
)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 45
#      37 embeddings: AzureOpenAIEmbeddings = AzureOpenAIEmbeddings(
#      38     azure_deployment=azure_deployment,
#      39     openai_api_version=azure_openai_api_version,
#      40     azure_endpoint=azure_endpoint,
#      41     api_key=azure_openai_api_key,
#      42 )
#      44 index_name: str = "langchain-vector-demo"
# ---> 45 vector_store: AzureSearch = AzureSearch(
#      46     azure_search_endpoint=vector_store_address,
#      47     azure_search_key=vector_store_password,
#      48     index_name=index_name,
#      49     embedding_function=embeddings.embed_query,
#      50 )
#
# ...

# %%
from langchain_community.retrievers import AzureAISearchRetriever

retriever = AzureAISearchRetriever(
    content_key="content", top_k=1, index_name="sincere-hook-r8w7kgrq5p"
)

# %%
import os

from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_community.retrievers import AzureAISearchRetriever
from langchain_community.vectorstores import AzureSearch
from langchain_openai import AzureOpenAIEmbeddings, OpenAIEmbeddings
from langchain_text_splitters import TokenTextSplitter
os.environ["AZURE_OPENAI_API_KEY"] = "5JYysB7CedH4g26m0WwUhPqDgkcvDKu6PWVmMTwHfKpvhwZ6pbizJQQJ99AKACfhMk5XJ3w3AAAAACOGjeKe"
os.environ["AZURE_AI_SEARCH_SERVICE_NAME"] = "https://ragservice123.search.windows.net"
os.environ["AZURE_AI_SEARCH_INDEX_NAME"] = "sincere-hook-r8w7kgrq5p"
os.environ["AZURE_AI_SEARCH_API_KEY"] = "kYTk8LtHQDvTb2LnYqG09vbeBNSwEB1287MrZbqkgFAzSeCNW3gO"
azure_endpoint: str = "https://gh018-m3fob2dq-swedencentral.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview"
azure_openai_api_key: str = "5JYysB7CedH4g26m0WwUhPqDgkcvDKu6PWVmMTwHfKpvhwZ6pbizJQQJ99AKACfhMk5XJ3w3AAAAACOGjeKe"
azure_openai_api_version: str = "2023-05-15"
azure_deployment: str = "text-embedding-ada-002"

# %%
os.environ["AZURE_AI_SEARCH_API_KEY"]

# %%
azure_endpoint: str = "https://genai-openai-madrasmavericks.openai.azure.com" #"https://gh018-m3fob2dq-swedencentral.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview"
azure_openai_api_key: str = "4fe881a4cfc9408897e96c250640c4b0" #"5JYysB7CedH4g26m0WwUhPqDgkcvDKu6PWVmMTwHfKpvhwZ6pbizJQQJ99AKACfhMk5XJ3w3AAAAACOGjeKe"
azure_openai_api_version: str = "2023-05-15"
azure_deployment: str = "text-embedding-ada-002"


vector_store_address: str = "https://ragservice123.search.windows.net"
vector_store_password: str = "kYTk8LtHQDvTb2LnYqG09vbeBNSwEB1287MrZbqkgFAzSeCNW3gO"

# %%
loader = TextLoader("Tickets.txt")
documents = loader.load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=500)
texts = text_splitter.split_documents(documents)

# %%
os.environ["AZURE_OPENAI_API_KEY"] = "4fe881a4cfc9408897e96c250640c4b0"
message = """
Answer this question using the provided context only.

{question}

Context:
{context}
"""



llm = ChatOpenAI(model="gpt-4o")

prompt = ChatPromptTemplate.from_messages([("human", message)])

rag_chain = {"context": retriever, "question": RunnablePassthrough()} | prompt | llm

# %%
rag_chain.invoke('test')
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 rag_chain.invoke('test')
#
# File ~\.conda\envs\hack\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File ~\.conda\envs\hack\Lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
# ...
